# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.simulations import simulation_time_dilation
from src.plots import plot_time_dilation

# velocity = 80% of speed of light
result = simulation_time_dilation(total_time=10, velocity=0.8 * 299_792_458)

plot_time_dilation(
    result['coordinate_time'],
    result['proper_time']
)
